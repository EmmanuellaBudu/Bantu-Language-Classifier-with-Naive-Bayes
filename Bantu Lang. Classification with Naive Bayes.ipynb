# %% [markdown]
# # Bantu Language Classification

# %% [markdown]
# Written by Emmanuella Budu and Boago Okgetheng. This a notebook that details how to construct a simple lanaguage classifier using Naive Bayes. The languages are Sestswana and Sesotho. The data used has been sourced from text from the Internet in th form of 'txt' files.

# %% [markdown]
# Importing the libraries

# %%
import pandas as pd

from string import punctuation

from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %% [markdown]
# Loading the data, text files contain data extracted from documents written in both the Setswana and Sesotho language

# %%
#Data
sesotho_data = open("..data/sesotho.txt', errors='ignore").read()
setswana_data = open("../data/setswana.txt', errors='ignore").read()

# %% [markdown]
# Preprocess the text document removing the stop words, spaces, etc.

# %%
#Preprocessing
stopwords=['a','e','i','o','u']

#tokenizer = RegexpTokenizer(r"\w+")

#convert to lowercase
sesotho_data=sesotho_data.lower()
setswana_data=setswana_data.lower()

#remove numbers
def strip_numbers(s):
    return''.join(c for c in s if not c.isdigit())

sesotho_data= strip_numbers(sesotho_data)
setswana_data= strip_numbers(setswana_data)

#remove punctuation
def strip_punctuation(s):
    return ''.join(c for c in s if c not in punctuation)

sesotho_data= strip_punctuation(sesotho_data)
setswana_data= strip_punctuation(setswana_data)


#Tokenize text
sesotho_token=word_tokenize(sesotho_data)
setswana_token=word_tokenize(setswana_data)

#remove stop words
sesotho_token = [word for word in sesotho_token if word not in stopwords]
setswana_token = [word for word in setswana_token if word not in stopwords]

print(sesotho_token)
# Out:
# ['molimo', 'bopa', 'leholimo', 'le', 'lefatse', 'tsimolohong', 'molimo', 'ne', 'hlole', 'leholimo', 'le', 'lefatse', 'lefatse', 'le', 'ne', 'le', 'se', 'na', 'sebopeho', 'le', 'se', 'na', 'letho', 'lefifi', 'le', 'ne', 'le', 'aparetse', 'boliba', 'moea', 'oa', 'molimo', 'ne', 'okaokela', 'metsi', 'molimo', 're', 'leseli', 'le', 'be', 'teng', 'eaba', 'leseli', 'le', 'ba', 'teng', 'molimo', 'bona', 'hore', 'leseli', 'le', 'letle', 'me', 'molimo', 'le', 'arohanya', 'le', 'lefifi', 'molimo', 're', 'leseli', 'ke', 'motseare', 'me', 're', 'lefifi', 'ke', 'bosiu', 'ha', 'phirima', 'ha', 'esa', 'ea', 'eba', 'letsatsi', 'la', 'pele', 'eaba', 'molimo', 're', 'lapi', 'le', 'be', 'teng', 'pakeng', 'tsa', 'metsi', 'ho', 'arohanya', 'metsi', 'ho', 'metsi', 'mang', 'molimo', 'etsa', 'loapi', 'ho', 'arohanya', 'metsi', 'kaholimo', 'ho', 'lona', 'le', 'metsi', 'katlase', 'ho', 'lona', 'ha', 'fela', 'ha', 'eba', 'joalo', 'molimo', 're', 'loapi', 'ke', 'leholimo', 'ha', 'phirima', 'ha', 'esa', 'ea', 'eba', 'letsatsi', 'la', 'bobeli', 'joale', 'molimo', 're', 'metsi', 'katlase', 'ho', 'leholimo', 'bokellane', 'sebakeng', 'se', 'le', 'seng', 'ho', 'hlah
'linonyana', 'li', 'ngatafale', 'lefatseng', 'ha', 'phirima', 'ha', 'esa', 'ea', 'eba', 'letsatsi', 'la', 'bohlano', 'eaba', 'molimo', 're', 'lefatse', 'le', 'hlahise', 'libdpuoa', 'tse', 'phelang', 'ka', 'mefuta', 'ea', 'tsona', 'makhomo', 'le', 'lihahabi', 'le', 'liphoofolo', 'tse', 'hlaha', 'ka', 'mefuta', 'ea', 'tsona', 'ha', 'fela', 'ha', 'eba', 'joalo', 'molimo', 'etsa', 'liphoofolo', 'tse', 'hlaha', 'ka', 'mefuta', 'ea', 'tsona', 'le', 'makhomo', 'ka', 'mefuta', 'ea', 'ona', 'le', 'lihahabi', 'tsohle', 'ka', 'mefuta', 'ea', 'tsona', 'molimo', 'bona', 'hore', 'hoo', 'ho', 'hotle', 'joale', 'molimo', 're', 're',  ...

# %% [markdown]
# Text data to Pandas dataframe

# %%
#Create a dataframe for Sesotho and Setswana text separately
sesotho_df= pd.DataFrame()

#Insert tokens in the dataframe along with the correct label
sesotho_df['text']=sesotho_token
sesotho_df['label']='sesotho'

setswana_df= pd.DataFrame()
setswana_df['text']=setswana_token
setswana_df['label']='setswana'

# Create a dataframe to store both Sesotho and Setswana text
train_df= pd.DataFrame()
train_df=sesotho_df.append(setswana_df)

#Shuffle the data frame
train_df = train_df.sample(frac=1).reset_index(drop=True)
train_df.head(50)
# Out:
#             text     label
# 0           rona   sesotho
# 1              ã  setswana
# 2             se   sesotho
# 3            mme  setswana
# 4           fela   sesotho
# 5           dilo  setswana
# 6             ha   sesotho
# 7             ba   sesotho
# 8          kgosi  setswana
# 9             le  setswana
# 10            ya  setswana
# 11      leholimo   sesotho
# 12            ka   sesotho
# 13        beleha   sesotho
# 14            sa   sesotho
# 15         tsona   sesotho
# 16         gonne  setswana
# 17        mosali   sesotho
# 18            ka   sesotho
# 19         letho   sesotho
# 20        molimo   sesotho
# 21         tsohe   sesotho
# 22            ga  setswana
# 23            ka  setswana
# 24            ka   sesotho
# 25        tsohle   sesotho
# 26           bea   sesotho
# 27            le  setswana
# 28            li   sesotho
# 29          lone  setswana
# 30        andrea  setswana
# 31            me  setswana
# 32      betsaita  setswana
# 33         kwana  setswana
# 34        morago  setswana
# 35          jele   sesotho
# 36            ke   sesotho
# 37            na   sesotho
# 38            le   sesotho
# 39       bophelo   sesotho
# 40           tse   sesotho
# 41         metsi   sesotho
# 42        johane  setswana
# 43            ba  setswana
# 44            ho   sesotho
# 45  morwarraagwe  setswana
# 46    tutuboloha   sesotho
# 47           ile   sesotho
# 48          lona   sesotho
# 49          bile   sesotho

# %% [markdown]
# Train and test sets

# %%
# Divide the dataset into training and testing sets
X= train_df.text

Y=train_df.label

X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.70, random_state = 0)

# %% [markdown]
# Term Frequency Vectorizer:
# 1. Output is a document term matrixConvert a collection of raw documents to a matrix of TF-IDF features.
# 2. Equivalent to CountVectorizer followed by TfidfTransformer.
# 3. We transform the text because the Naive Bayes classifier does not take text as input

# %%
#TF-IDF
tf_vect = TfidfVectorizer()

X_train_tf= tf_vect.fit_transform(X_train)
X_test_tf= tf_vect.transform(X_test)

print(tf_vect.vocabulary_)
# Out:
# {'efela': 94, 'leba': 245, 'boammaaruri': 38, 'œo': 573, 'yo': 561, 'khahlang': 221, 'lefatseng': 251, 'le': 243, 'serapeng': 493, 'litaba': 298, 're': 462, 'ntlha': 422, 'rene': 464, 'johane': 199, 'ne': 403, 'bana': 23, 'reng': 465, 'ka': 202, 'morena': 373, 'ho': 169, 'mphile': 393, 'nese': 407, 'motho': 384, 'itse': 184, 'serapa': 492, 'gagoâ': 138, 'se': 479, 'leina': 261, 'nyoloha': 429, 'ke': 212, 'li': 282, 'tla': 515, 'bogolo': 44, 'bophelo': 66, 'mangâ': 324, 'leholimo': 260, 'lefatse': 250, 'œnnyayaâ': 571, 'pula': 457, 'sefate': 482, 'la': 235, 'aparetse': 7, 'mesiaâ': 341, 'nqhekella': 419, 'sehubeng': 484, 'tsa': 525, 'seng': 488, 'joale': 196, 'bona': 56, 'ee': 92, 'moruti': 375, 'holima': 172, 'atang': 14, 'ea': 87, 'phetolelong': 452, 'lefifi': 254, 'latelang': 242, 'kamehla': 207, 'me': 334, 'motseare': 389, 'kaholimo': 205, 'molimo': 362, 'ile': 177, 'ngata': 408, 'bora': 67, 'mo': 345, 'sea': 480, 'lapi': 241, 'phirima': 453, 'rile': 467, 'ba': 15, 'ena': 102, 'hoo': 173, 'ha': 149, 'ene': 103, 'tlang': 517, 'edene': 91, 'go': 145, 'boela': 42, 'boraro': 68, 'fofang': 129, 'joalo': 197, 'lefika': 256, 'pet': 442, 'hobane': 170, 'andrea': 6, 'jesu': 195, 'gore': 148, 'asure': 13, 'bo': 37, 'litholoana': 299, 'loapi': 304, 'jwa': 201, 'nna': 413, 'ngoe': 410, 'œrabbiâ': 574, 'seo': 490, 'hore': 174, 'tsetsweng': 536, 'gagwe': 139, 'neileng': 404, 'etsetsa': 115, 'modimo': 348, 'bosiu': 69, 'eona': 109, 'lo': 303, 'botlalong': 71, 'sala': 478, 'tshola': 539, 'yoo': 563, 'tse': 530, 'ga': 136, 'ommeng': 432, 'hahabang': 152, 'mobung': 347, 'tletse': 520, 'kwa': 232, 'tswa': 552, 'wa': 559, 'mefuta': 335, 'sa': 476, 'œlo': 568, 'morwarraagwe': 378, 'phelang': 450, 'filipo': 128, 'esa': 110, 'nthaya': 421, 'eliaâ': 99, 'lona': 306, 'thusang': 511, 'mang': 323, 'eo': 107, 'simone': 499, 'eba': 90, 'lihahabi': 287, 'makhomo': 317, 'metsi': 342, 'godimo': 146, 'masapo': 328, 'bua': 75, 'thetsa': 510, 'tlale': 516, 'mamina': 322, 'malulong': 320, 'fela': 121, 'tena': 505, 'gagweâ': 140, 'halaletsa': 154, 'litlama': 300, 'ntse': 425, 'melisa': 338, 'tsimoloho': 543, 'bah': 19, 'nama': 397, 'kuang': 231, 'liphoofolo': 297, 'oo': 433, 'naha': 396, 'ja': 185, 'hara': 158, 'bopa': 63, 'teng': 506, 'fe': 119, 'kahobane': 204, 'lifate': 285, 'raya': 461, 'liaparo': 283, 'morago': 371, 'bonang': 57, 'tsamaea': 528, 'neilwe': 405, 'litlhapi': 301, 'gihone': 144, 'romileng': 471, 'khauta': 223, 'pele': 440, 'nathanaele': 400, 'mahlo': 315, 'tle': 519, 'apesa': 8, 'gonne': 147, 'ohle': 431, 'moå': 392, 'hae': 150, 'dumelang': 85, 'œke': 567, 'lerole': 275, 'balefi': 22, 'ya': 560, 'lefoko': 257, 'oa': 430, 'linonyana': 296, 'bitsoa': 36, 'boneâ': 60, 'be': 27, 'laela': 236, 'hlaha': 161, 'fologela': 133, 'tutuboloha': 554, 'phela': 449, 'monna': 367, 'mosali': 380, 'oona': 435, 'rona': 473, 'tshiamelo': 537, 'legodimong': 259, 'bobeli': 40, 'entseng': 106, 'nang': 398, 'mokhoa': 356, 'lebitso': 248, 'lesedi': 276, 'phallang': 446, 'arohanya': 11, 'kapa': 208, 'hlooho': 168, 'jang': 188, 'sefateng': 483, 'pe': 439, 'dilo': 81, 'tsaba': 526, 'rea': 463, 'lelekoa': 263, 'hlohonolofatsa': 166, 'moeeng': 351, 'motlodiwa': 386, 'lefatshe': 252, 'boletseng': 54, 'lenyenyane': 270, 'ling': 294, 'neng': 406, 'pakeng': 438, 'bong': 61, 'otlolla': 437, 'dikgolo': 80, 'bochabela': 41, 'letho': 278, 'khoba': 224, 'ope': 436, 'etsa': 114, 'barutwa': 25, 'fa': 118, 'morwamothoâ': 377, 'letsatsi': 280, 'mmotsa': 344, 'kolobetsa': 228, 'œmme': 569, 'eja': 95, 'file': 127, 'na': 394, 'tsoarisa': 547, 'linkong': 295, 'tsohle': 550, 'setsoano': 496, 'siamisang': 498, 'lena': 267, 'bile': 34, 'bethania': 31, 'matsatsi': 333, 'nne': 414, 'mohla': 354, 'feiee': 120, 'bidiwa': 33, 'tshupo': 540, 'life': 286, 'boleletseng': 52, 'leo': 271, 'araba': 9, 'hlajoe': 165, 'tsehlo': 532, 'mopa': 369, 'fetoha': 124, 'œbonang': 565, 'kateng': 210, 'lemoge': 266, 'esi': 112, 'bohareng': 45, 'thata': 508, 'eaba': 88, 'noha': 416, 'moso': 383, 'moholi': 355, 'eng' ...

# %% [markdown]
# Classification Model

# %%
#Naive Bayes Model
clf= MultinomialNB().fit(X_train_tf, y_train)

#Make predictions using test data
y_pred = clf.predict(X_test_tf)
#y_pred=clf.predict(tf_vect.transform(["modimo"]))
#print(y_pred)

#Calculate the accuracy
print ('ACCURACY:',accuracy_score(y_pred,y_test)*100)
# Out:
# ACCURACY: 81.32387706855792
